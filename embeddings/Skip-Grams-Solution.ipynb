# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6101 0.1875 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6398 0.1742 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4736 0.1741 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5743 0.1740 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5396 0.1730 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5006 0.1907 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5681 0.1919 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5561 0.1751 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4473 0.1755 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4377 0.1744 sec/batch
# Nearest to where: discipline, ablation, hound, monotheist, aufzeichnungen, almighty, melissa, antioxidants,
# Nearest to up: abbe, viridis, cloves, spectacular, hellenism, pyrotechnic, squat, pakistan,
# Nearest to a: greenstone, merlin, commentaries, holiness, entrance, dictates, the, vlachs,
# Nearest to these: phrase, kicking, nomad, loya, possum, unsympathetic, canaan, rangers,
# Nearest to by: see, underpants, ivorian, pir, herlihy, charged, beluga, confessional,
# Nearest to its: invade, heywood, feverish, revered, resembles, researchers, zirconia, aiding,
# Nearest to known: mainstays, cation, marti, engel, glucocorticoids, tsarevich, schickele, verlag,
# Nearest to such: columns, financially, regi, doyle, buffer, their, babrak, armament,
# Nearest to older: blew, turnpike, licensed, delights, stereotypes, moralistic, salomon, sparing,
# Nearest to prince: homogenic, corner, freemasons, essentially, kilkenny, inquests, beringer, blanc,
# Nearest to scale: loosened, cadillac, launch, lagrangian, wta, mayerling, prostaglandins, adult,
# Nearest to shown: trolling, singin, cleves, correspondences, par, badajoz, barbosa, cremated,
# Nearest to accepted: quang, strau, maxell, diary, limelight, processes, ravage, abacus,
# Nearest to primarily: taboos, grossman, zara, fetch, rich, partitas, egeria, codepage,
# Nearest to powers: beckham, expands, hydraulics, helton, stradella, addr, especial, laziness,
# Nearest to magazine: becoming, wikipedia, attain, shaker, assam, fp, operand, satirists,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4824 0.1795 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3640 0.1769 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3110 0.1736 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2430 0.1903 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2133 0.2041 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1337 0.1948 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0808 0.2042 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0680 0.1804 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0100 0.1794 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9792 0.1782 sec/batch
# Nearest to where: discipline, history, border, hound, demanding, almighty, chapterhouse, apparently,
# Nearest to up: abbe, spectacular, releasing, contrasted, cloves, pakistan, taiwan, pyrotechnic,
# Nearest to a: merlin, entrance, pittsburgh, scaled, surviving, greenstone, holiness, attempt,
# Nearest to these: phrase, kicking, nomad, portion, historically, ancestors, canaan, loya,
# Nearest to by: see, has, charged, accompany, intermediate, representation, its, jazz,
# Nearest to its: invade, researchers, revered, resembles, something, alaskan, carriage, magistracy,
# Nearest to known: employees, tsarevich, restrict, marti, cation, starred, miners, form,
# Nearest to such: their, columns, financially, using, appears, tyres, babrak, increased,
# Nearest to older: licensed, blew, stereotypes, moralistic, byword, hotel, confession, turnpike,
# Nearest to prince: homogenic, corner, essentially, freemasons, took, rather, original, turned,
# Nearest to scale: loosened, adult, launch, cadillac, if, would, lagrangian, decades,
# Nearest to shown: correspondences, trolling, cremated, singin, par, badajoz, repeated, combatants,
# Nearest to accepted: diary, quantities, processes, texts, constructed, limelight, bad, quang,
# Nearest to primarily: rich, taboos, spaces, grossman, zara, africa, allowed, ended,
# Nearest to powers: beckham, expands, laziness, problems, especial, root, journals, helton,
# Nearest to magazine: becoming, wikipedia, attain, assam, shaker, oft, fp, operand,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9339 0.1811 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9184 0.1795 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8772 0.1810 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8700 0.1877 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8217 0.1812 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8206 0.1806 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7862 0.1810 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7826 0.1798 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8021 0.1781 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7798 0.1815 sec/batch
# Nearest to where: discipline, demanding, border, almighty, history, hospital, hound, monotheist,
# Nearest to up: abbe, contrasted, pakistan, spectacular, hellenism, pyrotechnic, cloves, releasing,
# Nearest to a: merlin, entrance, surviving, pittsburgh, sing, scaled, majesty, greenstone,
# Nearest to these: phrase, kicking, historically, nomad, ancestors, rangers, canaan, undertaken,
# Nearest to by: see, charged, has, intermediate, accompany, representation, confessional, pir,
# Nearest to its: invade, researchers, aiding, revered, resembles, alaskan, smart, concurrent,
# Nearest to known: cation, marti, restrict, employees, verlag, scholarship, mainstays, theatrical,
# Nearest to such: financially, columns, their, appears, pvt, tyres, using, buffer,
# Nearest to older: licensed, blew, stereotypes, moralistic, turnpike, epithets, confession, delights,
# Nearest to prince: freemasons, corner, homogenic, essentially, took, turned, rear, beringer,
# Nearest to scale: loosened, launch, cadillac, adult, enormous, lagrangian, cofactor, geometrical,
# Nearest to shown: par, correspondences, trolling, cremated, combatants, ecsc, singin, ripped,
# Nearest to accepted: diary, quantities, limelight, strau, ravage, maxell, constructed, quang,
# Nearest to primarily: rich, grossman, taboos, ended, pronoun, associates, africa, expulsion,
# Nearest to powers: beckham, laziness, expands, journals, especial, root, fe, valhalla,
# Nearest to magazine: becoming, wikipedia, attain, assam, cardinal, shaker, oft, fp,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7619 0.1849 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7446 0.1789 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7112 0.1817 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7369 0.1803 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7635 0.1855 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7075 0.1800 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7230 0.1822 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7088 0.1807 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6960 0.1826 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6812 0.1802 sec/batch
# Nearest to where: discipline, monotheist, demanding, almighty, border, hound, mormonism, aufzeichnungen,
# Nearest to up: abbe, spectacular, hellenism, cloves, pakistan, pyrotechnic, piggy, squat,
# Nearest to a: merlin, entrance, greenstone, sing, pittsburgh, surviving, dictates, weeds,
# Nearest to these: phrase, kicking, nomad, canaan, historically, possum, unsympathetic, locations,
# Nearest to by: see, charged, confessional, pir, beluga, metternich, its, has,
# Nearest to its: invade, researchers, aiding, alaskan, smart, resembles, feverish, magistracy,
# Nearest to known: marti, mainstays, cation, denouncing, verlag, tsarevich, lya, employees,
# Nearest to such: financially, columns, their, buffer, tyres, pvt, appears, using,
# Nearest to older: blew, licensed, stereotypes, epithets, delights, turnpike, moralistic, salomon,
# Nearest to prince: freemasons, homogenic, took, corner, beringer, rear, essentially, wembley,
# Nearest to scale: loosened, cadillac, adult, cofactor, launch, limbs, lagrangian, kr,
# Nearest to shown: trolling, par, correspondences, cleves, combatants, ecsc, singin, ripped,
# Nearest to accepted: diary, strau, ravage, limelight, quantities, cz, reward, processes,
# Nearest to primarily: grossman, rich, taboos, pronoun, ministerial, zara, ended, expulsion,
# Nearest to powers: beckham, laziness, expands, journals, fe, especial, theologian, suleiman,
# Nearest to magazine: becoming, wikipedia, shaker, assam, cardinal, attain, odyssey, fp,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6683 0.1848 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6804 0.1826 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6060 0.1943 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6216 0.2124 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6376 0.1967 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6384 0.1962 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6078 0.1418 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5588 0.2085 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5180 0.1890 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4614 0.1863 sec/batch
# Nearest to where: discipline, monotheist, demanding, hound, almighty, border, mormonism, violates,
# Nearest to up: viridis, symbolising, cloves, spectacular, hellenism, piggy, pyrotechnic, qigong,
# Nearest to a: merlin, entrance, silt, ours, domain, allegheny, binary, radicalism,
# Nearest to these: phrase, nomad, kicking, canaan, locations, generally, historically, narrowing,
# Nearest to by: confessional, its, see, charged, pir, metternich, beluga, macedonian,
# Nearest to its: invade, researchers, aiding, alaskan, by, concurrent, smart, feverish,
# Nearest to known: mainstays, denouncing, verlag, combinatorics, lya, marti, cation, restrict,
# Nearest to such: financially, their, columns, using, tyres, pvt, appears, objects,
# Nearest to older: blew, stereotypes, licensed, epithets, turnpike, stillborn, salomon, instantaneous,
# Nearest to prince: freemasons, emperor, took, homogenic, beringer, corner, malcolm, dixit,
# Nearest to scale: loosened, mayerling, kr, adult, inability, cofactor, rarity, lagrangian,
# Nearest to shown: trolling, par, correspondences, cleves, eurydice, singin, combatants, ecsc,
# Nearest to accepted: diary, ravage, erratic, limelight, strau, celta, rigor, processes,
# Nearest to primarily: grossman, rich, alaskan, taboos, zara, pronoun, adf, africa,
# Nearest to powers: beckham, laziness, sado, expands, states, suleiman, murrow, especial,
# Nearest to magazine: wikipedia, becoming, shaker, assam, cardinal, fp, attain, odyssey,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4686 0.1841 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5006 0.1986 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4497 0.1974 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5193 0.2003 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4829 0.1826 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4344 0.1786 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4546 0.1783 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3926 0.1725 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4111 0.1729 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4389 0.1729 sec/batch
# Nearest to where: discipline, monotheist, hound, demanding, antioxidants, violates, aufzeichnungen, deviating,
# Nearest to up: symbolising, viridis, cloves, pyrotechnic, piggy, mourn, spectacular, qigong,
# Nearest to a: binary, merlin, ours, domain, hydroxy, scaled, improvise, cams,
# Nearest to these: phrase, generally, nomad, canaan, kicking, narrowing, locations, historically,
# Nearest to by: confessional, see, its, pir, charged, intermediate, beluga, metternich,
# Nearest to its: invade, researchers, alaskan, aiding, resembles, concurrent, by, elicit,
# Nearest to known: mainstays, denouncing, constitutionalism, lya, combinatorics, cation, verlag, walkway,
# Nearest to such: their, financially, columns, tyres, bronzino, appears, using, cmyk,
# Nearest to older: blew, stereotypes, licensed, stillborn, epithets, salomon, instantaneous, delights,
# Nearest to prince: freemasons, emperor, took, homogenic, beringer, corner, vallejo, wembley,
# Nearest to scale: loosened, mayerling, lagrangian, cofactor, systematised, geometrical, formed, inability,
# Nearest to shown: correspondences, trolling, par, cleves, eigenvalues, eurydice, ripped, cartographers,
# Nearest to accepted: celta, diary, ravage, texts, processes, erratic, strau, reward,
# Nearest to primarily: rich, grossman, alaskan, prospects, africa, zara, adf, ministerial,
# Nearest to powers: beckham, sado, laziness, states, expands, murrow, reviewing, inquiring,
# Nearest to magazine: wikipedia, becoming, shaker, assam, fp, odyssey, carrie, attain,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4307 0.1786 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4189 0.1851 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4418 0.1820 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4096 0.1717 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3907 0.1709 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4259 0.1728 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3890 0.1732 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3493 0.1709 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4466 0.1705 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3882 0.1724 sec/batch
# Nearest to where: discipline, monotheist, aufzeichnungen, border, germain, modernization, hound, filial,
# Nearest to up: symbolising, viridis, piggy, cloves, mourn, qigong, pyrotechnic, brim,
# Nearest to a: merlin, binary, ours, scaled, supple, attenuation, cams, dictates,
# Nearest to these: phrase, canaan, nomad, historically, kicking, generally, unsympathetic, adage,
# Nearest to by: pir, see, confessional, its, charged, intermediate, ivorian, sanity,
# Nearest to its: invade, researchers, elicit, feverish, alaskan, aiding, by, magistracy,
# Nearest to known: mainstays, denouncing, constitutionalism, combinatorics, lya, walkway, form, daria,
# Nearest to such: financially, their, columns, cmyk, buffer, appears, tyres, bronzino,
# Nearest to older: blew, stereotypes, stillborn, licensed, husband, moralistic, delights, instantaneous,
# Nearest to prince: emperor, freemasons, took, martyred, beringer, empress, homogenic, empire,
# Nearest to scale: mayerling, systematised, commodities, limbs, lagrangian, foodstuff, cofactor, loosened,
# Nearest to shown: correspondences, trolling, eigenvalues, par, patched, cleves, withering, ripped,
# Nearest to accepted: celta, processes, erratic, diary, vestry, rigor, predicament, texts,
# Nearest to primarily: rich, grossman, prospects, alaskan, adf, reprimanded, services, blocked,
# Nearest to powers: beckham, laziness, sado, states, suleiman, murrow, substitute, urbe,
# Nearest to magazine: wikipedia, becoming, shaker, carrie, assam, ewing, odyssey, fp,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3894 0.1749 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3992 0.1713 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3539 0.1722 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3530 0.1724 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3999 0.1715 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3905 0.1733 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3780 0.1721 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3906 0.1725 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3424 0.1724 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3013 0.1707 sec/batch
# Nearest to where: discipline, monotheist, aufzeichnungen, border, ablation, paramilitary, germain, filial,
# Nearest to up: symbolising, cloves, viridis, piggy, qigong, metropolises, pyrotechnic, improvise,
# Nearest to a: ours, binary, merlin, supple, attenuation, scaled, unshielded, thus,
# Nearest to these: phrase, kicking, locations, historically, generally, nomad, narrowing, canaan,
# Nearest to by: pir, confessional, its, see, intermediate, metternich, gpled, anachronistic,
# Nearest to its: invade, elicit, by, researchers, aiding, magistracy, alaskan, feverish,
# Nearest to known: mainstays, constitutionalism, denouncing, cordillera, fath, daria, pared, schickele,
# Nearest to such: financially, columns, their, appears, flaps, buffer, cmyk, common,
# Nearest to older: blew, stereotypes, stillborn, delights, husband, licensed, epithets, age,
# Nearest to prince: emperor, took, freemasons, beringer, martyred, empress, empire, homogenic,
# Nearest to scale: mayerling, commodities, limbs, contaminants, foodstuff, lagrangian, systematised, formed,
# Nearest to shown: par, correspondences, patched, eigenvalues, cartographers, ripped, singin, cleves,
# Nearest to accepted: celta, erratic, reservists, processes, rigor, vestry, strau, apply,
# Nearest to primarily: rich, prospects, alaskan, grossman, africa, reprimanded, adf, blocked,
# Nearest to powers: beckham, states, sado, laziness, constitutional, governmental, suleiman, murrow,
# Nearest to magazine: wikipedia, becoming, shaker, ewing, carrie, specials, fp, newspaper,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3430 0.1977 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3296 0.1726 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3838 0.1730 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3842 0.1722 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3977 0.1794 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2653 0.1861 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3067 0.1935 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3695 0.1928 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2160 0.1799 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2851 0.1854 sec/batch
# Nearest to where: discipline, monotheist, germain, paramilitary, border, aufzeichnungen, fv, ablation,
# Nearest to up: cloves, viridis, piggy, symbolising, mourn, qigong, brim, metropolises,
# Nearest to a: binary, supple, merlin, attenuation, unshielded, finesse, thus, ours,
# Nearest to these: phrase, kicking, unsympathetic, locations, historically, generally, nomad, owes,
# Nearest to by: pir, its, confessional, restructured, see, gpled, anachronistic, metternich,
# Nearest to its: invade, by, aiding, researchers, magistracy, elicit, feverish, exploitation,
# Nearest to known: mainstays, constitutionalism, denouncing, cordillera, fath, chronometers, schickele, mathison,
# Nearest to such: financially, columns, their, buffer, flaps, cmyk, appears, pvt,
# Nearest to older: age, blew, stereotypes, husband, versus, delights, moralistic, licensed,
# Nearest to prince: emperor, freemasons, took, martyred, beringer, empress, empire, homogenic,
# Nearest to scale: commodities, mayerling, contaminants, limbs, systematised, foodstuff, lagrangian, kr,
# Nearest to shown: par, patched, correspondences, eigenvalues, singin, cartographers, ripped, eurydice,
# Nearest to accepted: celta, rigor, vestry, diary, strau, citizenry, processes, reservists,
# Nearest to primarily: rich, prospects, alaskan, adf, africa, blocked, reprimanded, services,
# Nearest to powers: beckham, sado, laziness, constitutional, suleiman, states, nicolau, stradella,
# Nearest to magazine: wikipedia, shaker, ewing, newspaper, becoming, specials, carrie, interview,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3027 0.1813 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2889 0.1817 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3309 0.0809 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2517 0.1756 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2286 0.1764 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2171 0.1792 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1726 0.1806 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2147 0.1780 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2103 0.1785 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1694 0.1761 sec/batch
# Nearest to where: discipline, border, germain, monotheist, paramilitary, fv, hound, ablation,
# Nearest to up: cloves, viridis, symbolising, mourn, metropolises, lynx, piggy, qigong,
# Nearest to a: binary, attenuation, supple, scaled, unshielded, dictates, merlin, finesse,
# Nearest to these: phrase, kicking, locations, historically, generally, canaan, narrowing, unsympathetic,
# Nearest to by: its, pir, confessional, intermediate, see, which, charged, partitions,
# Nearest to its: invade, by, elicit, magistracy, aiding, alaskan, researchers, feverish,
# Nearest to known: mainstays, constitutionalism, fath, denouncing, mathison, chronometers, cordillera, severance,
# Nearest to such: financially, their, buffer, columns, encapsulating, cmyk, flaps, discontinuing,
# Nearest to older: age, versus, husband, blew, stereotypes, delights, median, stillborn,
# Nearest to prince: emperor, took, freemasons, beringer, martyred, homogenic, empress, bindusara,
# Nearest to scale: commodities, mayerling, lagrangian, systematised, limbs, formed, contaminants, kr,
# Nearest to shown: correspondences, patched, singin, eigenvalues, cleves, par, ripped, cartographers,
# Nearest to accepted: processes, diary, rigor, vestry, celta, strau, apply, witnessing,
# Nearest to primarily: rich, prospects, alaskan, africa, blocked, services, adf, reprimanded,
# Nearest to powers: beckham, sado, states, stradella, laziness, constitutional, suleiman, advises,
# Nearest to magazine: wikipedia, shaker, ewing, specials, newspaper, becoming, beria, fp,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2381 0.1931 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2138 0.2137 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2361 0.2014 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1481 0.1823 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1612 0.1776 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1764 0.1728 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1911 0.1710 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1954 0.1737 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1673 0.1722 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1640 0.1965 sec/batch
# Nearest to where: discipline, monotheist, germain, border, paramilitary, uninfected, fouled, ablation,
# Nearest to up: viridis, symbolising, cloves, piggy, releasing, lynx, mourn, brim,
# Nearest to a: binary, unshielded, attenuation, dictates, the, merlin, finesse, greenstone,
# Nearest to these: phrase, historically, kicking, locations, unsympathetic, narrowing, generally, nomad,
# Nearest to by: pir, its, see, confessional, intermediate, charged, restructured, anachronistic,
# Nearest to its: invade, aiding, by, feverish, researchers, alaskan, resembles, magistracy,
# Nearest to known: mainstays, fields, constitutionalism, form, mathison, decompressed, denouncing, walkway,
# Nearest to such: financially, their, columns, buffer, discontinuing, cmyk, encapsulating, flaps,
# Nearest to older: age, versus, husband, median, stereotypes, delights, blew, stillborn,
# Nearest to prince: emperor, freemasons, beringer, homogenic, took, martyred, bindusara, dixit,
# Nearest to scale: mayerling, systematised, lagrangian, contaminants, commodities, formed, foodstuff, neurologists,
# Nearest to shown: patched, par, ripped, cartographers, correspondences, singin, eigenvalues, cleves,
# Nearest to accepted: processes, vestry, strau, apply, diary, quantities, rigor, alimentarius,
# Nearest to primarily: rich, alaskan, prospects, africa, adf, geographers, services, embankment,
# Nearest to powers: beckham, constitutional, sado, states, suleiman, laziness, stradella, advises,
# Nearest to magazine: wikipedia, shaker, ewing, specials, newspaper, becoming, beria, epistolary,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1558 0.2121 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2135 0.2060 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1713 0.2019 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1711 0.2058 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1994 0.2167 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2020 0.2083 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1848 0.2208 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1708 0.2323 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1439 0.2146 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1901 0.1933 sec/batch
# Nearest to where: paramilitary, germain, discipline, monotheist, border, uninfected, proclaims, ablation,
# Nearest to up: viridis, cloves, symbolising, piggy, metropolises, elastic, qigong, dorian,
# Nearest to a: binary, the, supple, thus, attenuation, unshielded, counterexample, segments,
# Nearest to these: unsympathetic, phrase, locations, kicking, historically, generally, narrowing, redox,
# Nearest to by: pir, its, see, intermediate, representation, of, which, balfour,
# Nearest to its: invade, by, aiding, feverish, magistracy, smart, exploitation, competitors,
# Nearest to known: mainstays, constitutionalism, fields, mathison, decompressed, denouncing, form, lisan,
# Nearest to such: financially, columns, their, appears, buffer, cmyk, encapsulating, discontinuing,
# Nearest to older: age, husband, versus, stereotypes, stillborn, blew, licensed, delights,
# Nearest to prince: emperor, freemasons, beringer, homogenic, dixit, martyred, tyrant, bindusara,
# Nearest to scale: systematised, mayerling, lagrangian, foodstuff, inmarsat, limbs, commodities, formed,
# Nearest to shown: patched, conjugated, ripped, cartographers, eigenvalues, par, correspondences, restarts,
# Nearest to accepted: processes, vestry, strau, quantities, apply, alimentarius, dairy, diary,
# Nearest to primarily: rich, africa, alaskan, geographers, prospects, pronoun, preexistence, cucurbitaceae,
# Nearest to powers: beckham, constitutional, suleiman, advises, sado, states, governmental, laziness,
# Nearest to magazine: wikipedia, specials, newspaper, ewing, interview, shaker, becoming, opinions,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2062 0.1983 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1718 0.1985 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1752 0.2030 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1869 0.1965 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1281 0.1907 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1215 0.1755 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1706 0.1736 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1415 0.1733 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1942 0.1734 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2095 0.1730 sec/batch
# Nearest to where: germain, paramilitary, discipline, proclaims, border, monotheist, deviating, filial,
# Nearest to up: viridis, cloves, symbolising, qigong, piggy, mourn, dorian, debuting,
# Nearest to a: the, allegheny, supple, merlin, thus, surviving, juicy, pares,
# Nearest to these: unsympathetic, kicking, historically, phrase, locations, narrowing, generally, canaan,
# Nearest to by: pir, see, balfour, of, its, enrolling, representation, partitions,
# Nearest to its: invade, magistracy, exploitation, by, aiding, sparked, researchers, smart,
# Nearest to known: mainstays, constitutionalism, denouncing, schickele, mathison, fields, fath, furthered,
# Nearest to such: financially, columns, appears, buffer, their, proliferation, flaps, discontinuing,
# Nearest to older: age, husband, versus, stillborn, blew, stereotypes, delights, epithets,
# Nearest to prince: emperor, freemasons, beringer, homogenic, empress, dixit, martyred, gaetana,
# Nearest to scale: systematised, lagrangian, mayerling, foodstuff, commodities, limbs, inmarsat, conflated,
# Nearest to shown: patched, cartographers, ripped, conjugated, par, apace, eigenvalues, correspondences,
# Nearest to accepted: processes, vestry, apply, alimentarius, rigor, witnessing, strau, diary,
# Nearest to primarily: rich, alaskan, prospects, africa, attaches, blocked, cucurbitaceae, geographers,
# Nearest to powers: beckham, advises, sado, each, constitutional, stradella, swearing, huff,
# Nearest to magazine: wikipedia, newspaper, specials, ladd, interview, wisdom, ewing, shaker,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2601 0.1744 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1282 0.1725 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1484 0.1727 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1551 0.1718 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0449 0.1727 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1375 0.1738 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1581 0.1724 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1156 0.1731 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1524 0.0289 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1169 0.1763 sec/batch
# Nearest to where: germain, discipline, paramilitary, uninfected, radiate, proclaims, fv, vara,
# Nearest to up: viridis, piggy, cloves, symbolising, debuting, improvise, elastic, qigong,
# Nearest to a: the, binary, supple, nav, attenuation, inf, juicy, mcknight,
# Nearest to these: kicking, locations, unsympathetic, historically, phrase, generally, narrowing, encompass,
# Nearest to by: pir, which, its, of, representation, partitions, balfour, restructured,
# Nearest to its: invade, smart, exploitation, magistracy, by, suburban, researchers, sparked,
# Nearest to known: mainstays, fields, constitutionalism, denouncing, decompressed, chronometers, lisan, form,
# Nearest to such: financially, columns, buffer, flaps, cmyk, appears, discontinuing, their,
# Nearest to older: age, versus, husband, median, household, stillborn, females, licensed,
# Nearest to prince: emperor, freemasons, beringer, homogenic, empress, tyrant, dixit, martyred,
# Nearest to scale: systematised, commodities, lagrangian, inmarsat, foodstuff, conflated, trio, limbs,
# Nearest to shown: cartographers, ripped, patched, apace, conjugated, correspondences, par, eigenvalues,
# Nearest to accepted: processes, vestry, quantities, apply, witnessing, rigor, alimentarius, strau,
# Nearest to primarily: rich, alaskan, prospects, africa, titicaca, geographers, cucurbitaceae, attaches,
# Nearest to powers: beckham, advises, sado, constitutional, huff, stradella, swearing, each,
# Nearest to magazine: wikipedia, newspaper, specials, wisdom, ewing, ladd, guides, shaker,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0853 0.1791 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0823 0.1767 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1022 0.1789 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0582 0.1846 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0714 0.1760 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0508 0.1778 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0774 0.1761 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0750 0.2106 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1081 0.2032 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0233 0.1841 sec/batch
# Nearest to where: germain, paramilitary, uninfected, infinitely, fouled, pseudocode, deviating, radiate,
# Nearest to up: viridis, symbolising, piggy, cloves, mourn, debuting, desired, improvise,
# Nearest to a: the, is, supple, mcknight, thus, greenstone, attenuation, binary,
# Nearest to these: historically, narrowing, phrase, locations, kicking, generally, unsympathetic, disadvantage,
# Nearest to by: of, which, pir, its, balfour, the, restructured, see,
# Nearest to its: invade, by, exploitation, resembles, smart, suburban, magistracy, researchers,
# Nearest to known: mainstays, decompressed, constitutionalism, fields, form, denouncing, lisan, mathison,
# Nearest to such: financially, their, discontinuing, buffer, appears, flaps, cmyk, proliferation,
# Nearest to older: age, versus, husband, household, females, median, stillborn, families,
# Nearest to prince: emperor, beringer, freemasons, homogenic, iannis, bindusara, gaetana, dixit,
# Nearest to scale: systematised, inmarsat, mayerling, commodities, lagrangian, subscription, foodstuff, correction,
# Nearest to shown: cartographers, ripped, patched, apace, britannia, cleves, berke, invites,
# Nearest to accepted: processes, vestry, quantities, diary, witnessing, strau, ravage, rigor,
# Nearest to primarily: rich, alaskan, africa, geographers, prospects, cucurbitaceae, titicaca, groups,
# Nearest to powers: beckham, advises, each, stradella, constitutional, sado, huff, infinitely,
# Nearest to magazine: wikipedia, newspaper, wisdom, specials, guides, ladd, interview, ewing,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0184 0.1867 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0211 0.1847 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0048 0.1974 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0506 0.1912 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0913 0.1939 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0809 0.2151 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0573 0.2133 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0973 0.1942 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0382 0.1935 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0374 0.1958 sec/batch
# Nearest to where: paramilitary, vara, germain, uninfected, monotheist, infinitely, deviating, cayley,
# Nearest to up: viridis, piggy, improvise, debuting, move, symbolising, elastic, mourn,
# Nearest to a: the, is, counterexample, attenuation, thus, clearer, an, juicy,
# Nearest to these: unsympathetic, encompass, kicking, historically, generally, locations, narrowing, phrase,
# Nearest to by: of, which, see, the, representation, its, and, adaptations,
# Nearest to its: invade, by, exploitation, resembles, smart, researchers, competitors, suburban,
# Nearest to known: mainstays, fields, decompressed, constitutionalism, lisan, denouncing, mathison, miners,
# Nearest to such: financially, buffer, cmyk, discontinuing, their, columns, appears, encapsulating,
# Nearest to older: age, versus, husband, household, median, females, families, stillborn,
# Nearest to prince: emperor, freemasons, beringer, homogenic, gaetana, iannis, dixit, vipsanius,
# Nearest to scale: systematised, inmarsat, lagrangian, mayerling, formed, conflated, subscription, foodstuff,
# Nearest to shown: patched, cartographers, conjugated, ripped, venatici, eigenvalues, restarts, correspondences,
# Nearest to accepted: processes, quantities, apply, vestry, dairy, witnessing, borderland, rigor,
# Nearest to primarily: rich, cucurbitaceae, geographers, alaskan, groups, africa, titicaca, frightening,
# Nearest to powers: beckham, advises, constitutional, sado, huff, stradella, infinitely, swearing,
# Nearest to magazine: wikipedia, wisdom, newspaper, ladd, interview, specials, guides, ewing,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0550 0.2200 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1091 0.2361 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0438 0.2082 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0578 0.2072 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0737 0.2045 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0594 0.1962 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0627 0.1942 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0572 0.1969 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1254 0.1937 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0781 0.1898 sec/batch
# Nearest to where: paramilitary, vara, germain, discipline, proclaims, uninfected, monotheist, ambon,
# Nearest to up: viridis, piggy, elastic, improvise, bromwich, desired, symbolising, mourn,
# Nearest to a: the, instead, is, supple, juicy, thus, finesse, surviving,
# Nearest to these: unsympathetic, kicking, narrowing, canaan, encompass, possum, locations, phrase,
# Nearest to by: of, which, pir, the, see, representation, its, balfour,
# Nearest to its: invade, exploitation, by, smart, magistracy, sparked, suburban, aiding,
# Nearest to known: mainstays, lisan, constitutionalism, mathison, decompressed, fields, miners, fath,
# Nearest to such: financially, buffer, cmyk, columns, discontinuing, appears, flaps, encapsulating,
# Nearest to older: age, versus, husband, household, median, females, families, stillborn,
# Nearest to prince: emperor, freemasons, beringer, empress, bindusara, gaetana, dixit, malayan,
# Nearest to scale: systematised, conflated, subscription, foodstuff, inmarsat, mayerling, trio, lagrangian,
# Nearest to shown: cartographers, conjugated, patched, ripped, sentiment, restarts, britannia, venatici,
# Nearest to accepted: processes, quantities, apply, vestry, borderland, witnessing, ravage, dairy,
# Nearest to primarily: rich, cucurbitaceae, geographers, groups, alaskan, africa, grossman, spaces,
# Nearest to powers: beckham, constitutional, advises, swearing, dissolve, huff, sado, especial,
# Nearest to magazine: wikipedia, newspaper, wisdom, guides, ladd, specials, interview, ewing,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0615 0.1908 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0113 0.1859 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0505 0.1845 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0517 0.1899 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0760 0.1851 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1024 0.1816 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1209 0.1793 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0373 0.1803 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0403 0.1792 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0588 0.1767 sec/batch
# Nearest to where: vara, discipline, germain, paramilitary, ladykillers, proclaims, uninfected, monotheist,
# Nearest to up: viridis, piggy, mourn, debuting, move, bromwich, symbolising, improvise,
# Nearest to a: the, is, supple, juicy, finesse, unshielded, riesz, dictates,
# Nearest to these: kicking, narrowing, historically, possum, encompass, locations, canaan, unsympathetic,
# Nearest to by: which, pir, of, the, its, headed, was, and,
# Nearest to its: invade, by, smart, researchers, exploitation, magistracy, separate, aiding,
# Nearest to known: mainstays, fields, decompressed, denouncing, constitutionalism, lisan, furthered, fath,
# Nearest to such: financially, buffer, appears, columns, cmyk, flaps, their, noncombatant,
# Nearest to older: age, versus, husband, household, females, median, families, householder,
# Nearest to prince: emperor, freemasons, beringer, gaetana, empress, inquests, malayan, dixit,
# Nearest to scale: conflated, systematised, subscription, trio, mayerling, inmarsat, lagrangian, loosened,
# Nearest to shown: cartographers, patched, ripped, conjugated, sentiment, venatici, restarts, britannia,
# Nearest to accepted: vestry, processes, quantities, borderland, ravage, witnessing, apply, strau,
# Nearest to primarily: rich, cucurbitaceae, geographers, groups, alaskan, kfc, grossman, africa,
# Nearest to powers: beckham, advises, huff, especial, sado, stradella, lambda, vtol,
# Nearest to magazine: wikipedia, newspaper, wisdom, ladd, guides, specials, ewing, interview,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0171 0.1813 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0352 0.1781 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0388 0.1875 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0164 0.1816 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0627 0.1853 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0370 0.1810 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0355 0.1868 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9802 0.1946 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9903 0.1851 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9573 0.2037 sec/batch
# Nearest to where: discipline, uninfected, paramilitary, vara, germain, proclaims, monotheist, ladykillers,
# Nearest to up: viridis, mourn, desired, symbolising, piggy, move, elastic, cloves,
# Nearest to a: the, is, an, dictates, supple, juicy, thus, finesse,
# Nearest to these: encompass, narrowing, kicking, possum, bitstream, unsympathetic, historically, revisions,
# Nearest to by: which, of, the, pir, its, was, adaptations, and,
# Nearest to its: invade, by, smart, exploitation, magistracy, researchers, resembles, mapmakers,
# Nearest to known: mainstays, lisan, fath, fields, constitutionalism, decompressed, denouncing, the,
# Nearest to such: financially, buffer, their, appears, cmyk, flaps, discontinuing, columns,
# Nearest to older: age, household, versus, husband, median, females, families, householder,
# Nearest to prince: emperor, beringer, freemasons, iannis, gaetana, malayan, empress, inquests,
# Nearest to scale: conflated, systematised, subscription, inmarsat, trio, commodities, adjustable, lagrangian,
# Nearest to shown: patched, sentiment, cartographers, ripped, conjugated, venatici, restarts, sgi,
# Nearest to accepted: processes, quantities, vestry, ravage, witnessing, dairy, borderland, limelight,
# Nearest to primarily: rich, cucurbitaceae, geographers, groups, kfc, alaskan, associates, embankment,
# Nearest to powers: beckham, huff, especial, advises, sado, swearing, vied, lambda,
# Nearest to magazine: wikipedia, newspaper, wisdom, ladd, guides, specials, interview, opinions,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9918 0.2148 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9620 0.2187 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0216 0.2146 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0310 0.2109 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0033 0.2121 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9914 0.1937 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9379 0.1879 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9527 0.1827 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9609 0.1764 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9633 0.1756 sec/batch
# Nearest to where: uninfected, vara, paramilitary, germain, monotheist, ambon, discipline, ladykillers,
# Nearest to up: viridis, move, elastic, desired, mourn, debuting, improvise, symbolising,
# Nearest to a: the, is, an, supple, thus, adapters, finesse, to,
# Nearest to these: encompass, narrowing, historically, generally, redox, supplement, locations, canaan,
# Nearest to by: which, of, the, adaptations, pir, and, a, its,
# Nearest to its: invade, resembles, smart, exploitation, researchers, by, preeminence, aiding,
# Nearest to known: mainstays, decompressed, fields, lisan, fath, denouncing, brut, furthered,
# Nearest to such: financially, their, discontinuing, appears, buffer, flaps, discovering, columns,
# Nearest to older: age, versus, household, husband, families, median, females, householder,
# Nearest to prince: emperor, beringer, freemasons, iannis, homogenic, inquests, gaetana, beatle,
# Nearest to scale: conflated, systematised, subscription, mayerling, inmarsat, trio, adjustable, loosened,
# Nearest to shown: cartographers, sentiment, patched, ripped, conjugated, uracil, venatici, invites,
# Nearest to accepted: processes, quantities, vestry, ravage, dairy, borderland, witnessing, strau,
# Nearest to primarily: rich, cucurbitaceae, groups, geographers, associates, kfc, alaskan, cam,
# Nearest to powers: beckham, huff, advises, especial, constitutional, swearing, vied, urbe,
# Nearest to magazine: wikipedia, newspaper, wisdom, guides, ladd, tootsie, specials, interview,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9693 0.1788 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0222 0.1816 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9495 0.1771 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0126 0.1739 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0350 0.1759 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9604 0.1818 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9922 0.1989 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9957 0.1825 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9922 0.1819 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9986 0.1796 sec/batch
# Nearest to where: uninfected, vara, paramilitary, proclaims, germain, ladykillers, diploid, ambon,
# Nearest to up: viridis, elastic, move, bromwich, improvise, piggy, desired, symbolising,
# Nearest to a: the, is, an, to, supple, mcknight, from, juicy,
# Nearest to these: encompass, historically, revisions, supplement, unsympathetic, arbitrariness, generally, tutors,
# Nearest to by: of, which, the, and, pir, its, see, balfour,
# Nearest to its: invade, smart, by, resembles, researchers, baptisms, feverish, aveiro,
# Nearest to known: mainstays, furthered, decompressed, lisan, denouncing, fath, fields, ideologically,
# Nearest to such: financially, appears, discontinuing, their, involving, conflict, columns, thrillers,
# Nearest to older: age, versus, household, husband, families, median, females, stillborn,
# Nearest to prince: emperor, beringer, empress, inquests, gaetana, freemasons, iannis, beatle,
# Nearest to scale: conflated, systematised, subscription, inmarsat, trio, cumbria, adjustable, lagrangian,
# Nearest to shown: cartographers, sentiment, uracil, conjugated, patched, invites, ripped, amines,
# Nearest to accepted: processes, vestry, quantities, ravage, dairy, apply, witnessing, acceptance,
# Nearest to primarily: rich, geographers, cucurbitaceae, groups, kfc, frightening, associates, meijer,
# Nearest to powers: beckham, advises, huff, constitutional, especial, swearing, responsibilities, deterrence,
# Nearest to magazine: wikipedia, newspaper, wisdom, guides, ladd, warners, tootsie, interview,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9979 0.1909 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9798 0.1835 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9816 0.1813 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0300 0.1818 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0096 0.1794 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0089 0.1785 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9970 0.1789 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9709 0.1860 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9613 0.1942 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0073 0.1916 sec/batch
# Nearest to where: uninfected, ladykillers, diploid, paramilitary, proclaims, monotheist, vara, discipline,
# Nearest to up: viridis, elastic, desired, mourn, symbolising, openly, improvise, contraband,
# Nearest to a: the, is, an, to, thus, supple, allegheny, from,
# Nearest to these: narrowing, encompass, historically, supplement, arbitrariness, unsympathetic, generally, disadvantage,
# Nearest to by: which, of, the, and, pir, headed, was, balfour,
# Nearest to its: invade, smart, by, separate, researchers, exploitation, formerly, competitors,
# Nearest to known: mainstays, decompressed, lisan, fath, fields, the, furthered, denouncing,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8807 0.1783 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8511 0.1792 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8392 0.2042 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8662 0.2001 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9222 0.1830 sec/batch
# Nearest to where: diploid, waller, ladykillers, ambon, vara, eisenman, fees, confederal,
# Nearest to up: they, never, mourn, move, debuting, squat, bromwich, elastic,
# Nearest to a: the, is, of, to, an, from, and, as,
# Nearest to these: many, and, have, linked, pcm, supplement, gabriel, possum,
# Nearest to by: of, the, which, and, a, was, been, adaptations,
# Nearest to its: the, a, by, formerly, duc, of, separate, interpretation,
# Nearest to known: the, a, name, as, uses, of, based, such,
# Nearest to such: as, is, a, to, often, many, involving, appears,
# Nearest to older: age, versus, females, household, families, husband, median, younger,
# Nearest to prince: emperor, titles, inquests, empress, gaetana, iannis, beringer, referenda,
# Nearest to scale: conflated, scorch, subscription, wilkinson, pitched, chandeliers, cumbria, codasyl,
# Nearest to shown: sentiment, puranas, uracil, the, sgi, amines, revealed, integer,
# Nearest to accepted: acceptance, dairy, ravage, ebb, witnessing, processes, snacks, supposedly,
# Nearest to primarily: rich, cucurbitaceae, geographers, disregards, meijer, cbd, spaces, anticonvulsants,
# Nearest to powers: huff, beckham, advises, especial, series, lambda, theism, immanent,
# Nearest to magazine: newspaper, wikipedia, magazines, tootsie, articles, publications, ladd, warners,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8419 0.1853 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8160 0.1834 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8374 0.1830 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8485 0.1848 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8585 0.1988 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8797 0.1879 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8846 0.1823 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8549 0.1821 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8985 0.1910 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8617 0.1952 sec/batch
# Nearest to where: diploid, ladykillers, father, ambon, friends, executed, waller, eisenman,
# Nearest to up: never, they, mourn, move, labour, bestow, ebionites, bromwich,
# Nearest to a: the, of, is, an, and, to, from, as,
# Nearest to these: and, many, have, long, possum, elders, extent, gabriel,
# Nearest to by: the, of, which, and, a, was, been, also,
# Nearest to its: the, a, formerly, by, duc, hammerheads, invade, transformed,
# Nearest to known: the, a, name, as, of, based, lisan, have,
# Nearest to such: as, a, is, appears, often, to, many, be,
# Nearest to older: age, versus, household, females, families, younger, husband, median,
# Nearest to prince: emperor, empress, inquests, titles, princess, referenda, gaetana, beringer,
# Nearest to scale: subscription, wilkinson, conflated, scorch, codasyl, trio, larger, efficiencies,
# Nearest to shown: puranas, sgi, uracil, integer, sentiment, the, amines, revealed,
# Nearest to accepted: acceptance, dairy, ravage, ebb, rigor, borderland, supposedly, witnessing,
# Nearest to primarily: rich, disregards, geographers, cucurbitaceae, meijer, anticonvulsants, spaces, associates,
# Nearest to powers: huff, beckham, advises, series, dissolve, especial, constitutional, senators,
# Nearest to magazine: newspaper, wikipedia, magazines, articles, publications, wisdom, tootsie, warners,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8906 0.2189 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8568 0.2167 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8291 0.1932 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8685 0.1966 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8870 0.2040 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8351 0.2077 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9818 0.2165 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8978 0.2076 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9132 0.1992 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8139 0.1924 sec/batch
# Nearest to where: diploid, ladykillers, father, friends, waller, ambon, eisenman, executed,
# Nearest to up: they, never, mourn, openly, debuting, booker, often, labour,
# Nearest to a: the, is, of, and, to, as, from, an,
# Nearest to these: and, many, have, long, possum, extent, historically, generally,
# Nearest to by: the, of, which, and, was, a, been, its,
# Nearest to its: the, by, a, formerly, separate, of, interpretation, has,
# Nearest to known: the, a, name, as, of, such, based, uses,
# Nearest to such: as, is, a, appears, to, often, known, be,
# Nearest to older: age, versus, household, females, younger, families, husband, spread,
# Nearest to prince: emperor, empress, titles, inquests, princess, beringer, intersected, iannis,
# Nearest to scale: subscription, pitched, codasyl, scorch, trio, conflated, wilkinson, efficiencies,
# Nearest to shown: puranas, revealed, sgi, sentiment, integer, remade, uracil, radon,
# Nearest to accepted: acceptance, ravage, supposedly, dairy, rigor, statement, ebb, favor,
# Nearest to primarily: rich, disregards, geographers, associates, cucurbitaceae, meijer, cbd, anticonvulsants,
# Nearest to powers: huff, beckham, series, advises, especial, villainous, lambda, vied,
# Nearest to magazine: newspaper, wikipedia, magazines, tootsie, articles, wisdom, publications, warners,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7980 0.1996 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8545 0.1958 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7890 0.1912 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8685 0.1871 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8436 0.1865 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8530 0.1844 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9042 0.0898 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8180 0.1849 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8318 0.1971 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8266 0.2006 sec/batch
# Nearest to where: diploid, ladykillers, ambon, father, plundered, confederal, eisenman, executed,
# Nearest to up: never, they, mourn, often, move, labour, openly, booker,
# Nearest to a: the, of, is, and, an, to, from, as,
# Nearest to these: many, possum, long, supplement, have, and, gabriel, generally,
# Nearest to by: the, of, which, and, a, was, to, also,
# Nearest to its: a, the, by, formerly, separate, interpretation, so, transformed,
# Nearest to known: the, a, name, as, such, fath, lisan, of,
# Nearest to such: as, a, often, to, is, appears, involving, many,
# Nearest to older: age, versus, household, females, families, younger, husband, spread,
# Nearest to prince: emperor, empress, titles, inquests, gaetana, princess, iannis, ornithologist,
# Nearest to scale: subscription, codasyl, pitched, larger, trio, conflated, scorch, chromatically,
# Nearest to shown: revealed, puranas, sgi, result, integer, invites, sentiment, radon,
# Nearest to accepted: acceptance, supposedly, iguana, ravage, snacks, witnessing, dairy, absentia,
# Nearest to primarily: rich, anticonvulsants, disregards, cucurbitaceae, kfc, rimfire, meijer, associates,
# Nearest to powers: huff, beckham, series, advises, especial, villainous, vied, theism,
# Nearest to magazine: newspaper, magazines, wikipedia, tootsie, wisdom, publications, warners, articles,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8211 0.2192 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8460 0.1944 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8568 0.1939 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7869 0.1956 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8611 0.2081 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8110 0.2160 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8605 0.1868 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7303 0.1869 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7818 0.1862 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8112 0.1856 sec/batch
# Nearest to where: diploid, as, confederal, ladykillers, ambon, of, option, an,
# Nearest to up: never, they, move, mourn, labour, find, often, while,
# Nearest to a: the, is, of, and, an, to, from, as,
# Nearest to these: and, many, have, which, to, supplement, generally, more,
# Nearest to by: of, the, which, and, a, was, to, also,
# Nearest to its: the, a, by, formerly, of, to, and, separate,
# Nearest to known: the, a, name, as, based, such, uses, of,
# Nearest to such: as, is, often, a, to, many, particular, appears,
# Nearest to older: age, versus, household, females, younger, families, spread, median,
# Nearest to prince: emperor, empress, emotions, inquests, titles, beringer, iannis, referenda,
# Nearest to scale: subscription, wilkinson, codasyl, efficiencies, conflated, scorch, pitched, trio,
# Nearest to shown: puranas, revealed, sentiment, remade, sgi, the, integer, invites,
# Nearest to accepted: acceptance, ravage, supposedly, iguana, witnessing, scientific, snacks, metamorphic,
# Nearest to primarily: rich, disregards, cucurbitaceae, rimfire, anticonvulsants, geographers, cbd, associates,
# Nearest to powers: huff, beckham, advises, series, dissolve, especial, villainous, theism,
# Nearest to magazine: newspaper, wikipedia, magazines, tootsie, wisdom, publications, guides, articles,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7259 0.1891 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8228 0.1858 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8427 0.1854 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8591 0.1853 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8223 0.1840 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8709 0.1833 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8488 0.1841 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8170 0.1834 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8047 0.1842 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8426 0.1835 sec/batch
# Nearest to where: ladykillers, waller, diploid, ambon, father, coldest, friends, vara,
# Nearest to up: never, they, move, labour, mourn, while, find, improvise,
# Nearest to a: the, is, of, from, an, and, to, in,
# Nearest to these: and, many, have, to, long, which, supplement, possum,
# Nearest to by: of, the, which, and, a, was, in, also,
# Nearest to its: the, a, by, formerly, of, so, has, to,
# Nearest to known: the, a, name, as, based, of, such, this,
# Nearest to such: as, a, often, is, many, to, be, particular,
# Nearest to older: age, versus, household, younger, families, females, spread, stillborn,
# Nearest to prince: emperor, empress, titles, inquests, emotions, princess, iannis, intersected,
# Nearest to scale: subscription, larger, scorch, pitched, wilkinson, oregon, conflated, trio,
# Nearest to shown: revealed, puranas, sentiment, amines, the, remade, broadcast, sgi,
# Nearest to accepted: acceptance, supposedly, dairy, snacks, iguana, witnessing, ravage, eu,
# Nearest to primarily: rich, disregards, anticonvulsants, cucurbitaceae, geographers, frightening, cbd, agu,
# Nearest to powers: huff, advises, beckham, dissolve, series, senators, theism, especial,
# Nearest to magazine: newspaper, magazines, wikipedia, tootsie, articles, publications, wisdom, ladd,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9007 0.1885 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8024 0.1849 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8132 0.1815 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8256 0.1802 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8887 0.1790 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8274 0.1801 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8270 0.1804 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8574 0.1805 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8117 0.1795 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8002 0.1793 sec/batch
# Nearest to where: diploid, ladykillers, as, ambon, executed, confederal, friends, fusional,
# Nearest to up: never, they, move, labour, a, improvise, while, it,
# Nearest to a: the, of, is, from, and, to, an, in,
# Nearest to these: and, many, have, to, long, generally, possum, extent,
# Nearest to by: of, the, which, and, a, was, in, also,
# Nearest to its: the, a, of, to, by, has, and, formerly,
# Nearest to known: the, a, name, of, as, was, based, such,
# Nearest to such: as, often, a, to, many, is, be, the,
# Nearest to older: age, versus, household, younger, families, spread, females, stillborn,
# Nearest to prince: emperor, empress, emotions, inquests, titles, iannis, princess, beringer,
# Nearest to scale: subscription, scorch, larger, pitched, wilkinson, codasyl, oregon, efficiencies,
# Nearest to shown: revealed, sentiment, invites, puranas, remade, uracil, amines, sgi,
# Nearest to accepted: acceptance, scientific, supposedly, witnessing, ravage, snacks, dairy, though,
# Nearest to primarily: rich, disregards, available, cucurbitaceae, anticonvulsants, distinct, geographers, cbd,
# Nearest to powers: huff, advises, beckham, dissolve, series, theism, constitutional, especial,
# Nearest to magazine: newspaper, magazines, wikipedia, tootsie, publications, articles, ladd, guides,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8720 0.1821 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8319 0.1826 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9330 0.1816 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9084 0.1818 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8903 0.1802 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8238 0.1804 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8110 0.1791 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8072 0.1941 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7310 0.1794 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8769 0.1807 sec/batch
# Nearest to where: ladykillers, diploid, father, friends, fusional, option, executed, confederal,
# Nearest to up: never, they, labour, move, a, crc, mourn, how,
# Nearest to a: the, is, of, from, to, and, in, an,
# Nearest to these: and, many, to, have, which, long, generally, linked,
# Nearest to by: the, of, which, and, a, was, also, in,
# Nearest to its: the, a, by, of, formerly, transformed, magic, and,
# Nearest to known: the, a, as, name, of, such, was, uses,
# Nearest to such: as, often, many, is, a, to, be, known,
# Nearest to older: age, versus, household, females, families, spread, younger, median,
# Nearest to prince: emperor, emotions, empress, titles, inquests, referenda, iannis, beringer,
# Nearest to scale: subscription, larger, scorch, pitched, codasyl, efficiencies, conflated, keys,
# Nearest to shown: revealed, remade, amines, untenable, integer, uracil, the, puranas,
# Nearest to accepted: acceptance, snacks, supposedly, iguana, absentia, ravage, witnessing, scientific,
# Nearest to primarily: rich, anticonvulsants, available, disregards, cucurbitaceae, agu, cbd, kfc,
# Nearest to powers: huff, beckham, advises, series, villainous, dissolve, vied, awesome,
# Nearest to magazine: magazines, newspaper, wikipedia, articles, publications, tootsie, ladd, investigative,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8427 0.1831 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8577 0.1799 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /home/sunggeun/anaconda2/envs/tensorflow/lib/python3.5/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
